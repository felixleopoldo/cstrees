# %% [markdown]
# # Plotting

# %%
import random
import pandas as pd
import time
import logging, sys
import matplotlib.pyplot as plt
import pathlib
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d

# %%
df = pd.read_csv("timings.csv")
#df_plot = df.groupby(["p", "max_cvars"])["time"].mean().reset_index()
df_plot = df
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(df_plot["max_cvars"], df_plot['p'], df_plot['time'])
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()

# %%
from scipy.special import loggamma

# %%
threedee = plt.figure().gca()
threedee.scatter(df["time"], df['cvar_prob'], df['prop_colored'])
threedee.set_xlabel('cvar_prob')
threedee.set_ylabel('prop_colored')
threedee.set_zlabel('time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/f/l/flrios/git/CStrees/src/plotting.ipynb Cell 4 in 5
#       <a href='vscode-notebook-cell:/home/f/l/flrios/git/CStrees/src/plotting.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> threedee.set_xlabel('cvar_prob')
#       <a href='vscode-notebook-cell:/home/f/l/flrios/git/CStrees/src/plotting.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> threedee.set_ylabel('prop_colored')
# ----> <a href='vscode-notebook-cell:/home/f/l/flrios/git/CStrees/src/plotting.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> threedee.set_zlabel('time')
#       <a href='vscode-notebook-cell:/home/f/l/flrios/git/CStrees/src/plotting.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_zlabel'
